# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h2>Import Data</h2>

# %%
#Read the three files as dataframes
file1 = pd.read_csv('file1.csv')
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file2 = pd.read_csv('file2.csv')
file2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
file3 = pd.read_csv('file3.csv')
file3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
#show dataframe's shape=
df = pd.DataFrame(columns = file1.columns)
df
# Out:
# Empty DataFrame
# Columns: [Customer, ST, GENDER, Education, Customer Lifetime Value, Income, Monthly Premium Auto, Number of Open Complaints, Policy Type, Vehicle Class, Total Claim Amount]
# Index: []

# %%
df.shape
# Out:
# (0, 11)

# %%
type(file1)
# Out:
# pandas.core.frame.DataFrame

# %%
#standardize column names
column_names = file1.columns
column_names
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
file3 = file3.rename(columns={"State": "ST", "Gender": "GENDER"})

# %%
#concatenate files
data_set = pd.concat([file1, file2, file3], axis=0)
data_set
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
data_set.columns = [i.lower().replace(" ", "_") for i in  data_set.columns]
data_set.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')

# %%
#identifing numerical columns
data_set.select_dtypes(include=np.number)
# Out:
#        income  monthly_premium_auto  total_claim_amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 7065  71941.0                  73.0          198.234764
# 7066  21604.0                  79.0          379.200000
# 7067      0.0                  85.0          790.784983
# 7068  21941.0                  96.0          691.200000
# 7069      0.0                  77.0          369.600000
#
# [12074 rows x 3 columns]

# %%
#identify categorical columns
data_set.select_dtypes(include=object)
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer_lifetime_value number_of_open_complaints     policy_type  \
# 0                        NaN                    1/0/00   Personal Auto
# 1                 697953.59%                    1/0/00   Personal Auto
# 2                1288743.17%                    1/0/00   Personal Auto
# ...

# %% [markdown]
# <h2>Data Cleaning Operations</h2>

# %%
#drop 'education' and 'number_of_open_complaints' columns
columns_drop = ['education', 'number_of_open_complaints']

# %%
data_set = data_set.drop(columns_drop, axis = 1)

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer                 9137 non-null   object
#  1   st                       9137 non-null   object
#  2   gender                   9015 non-null   object
#  3   customer_lifetime_value  9130 non-null   object
#  4   income                   9137 non-null   float64
#  5   monthly_premium_auto     9137 non-null   float64
#  6   policy_type              9137 non-null   object
#  7   vehicle_class            9137 non-null   object
#  8   total_claim_amount       9137 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 943.3+ KB

# %%
nulls_df = pd.DataFrame(round(data_set.isna().sum()/len(data_set)*100,2))

# %%
#correct 'customer_lifetime_value' from percentage to numerical value
clv_num = data_set['customer_lifetime_value']
clv_num
# Out:
# 0               NaN
# 1        697953.59%
# 2       1288743.17%
# 3        764586.18%
# 4        536307.65%
#            ...
# 7065    23405.98798
# 7066    3096.511217
# 7067    8163.890428
# 7068    7524.442436
# 7069    2611.836866
# Name: customer_lifetime_value, Length: 12074, dtype: object

# %%
type(clv_num)
# Out:
# pandas.core.series.Series

# %%
clv_num = data_set['customer_lifetime_value'].str.replace('%','')

# %%
clv_num
# Out:
# 0              NaN
# 1        697953.59
# 2       1288743.17
# 3        764586.18
# 4        536307.65
#            ...
# 7065           NaN
# 7066           NaN
# 7067           NaN
# 7068           NaN
# 7069           NaN
# Name: customer_lifetime_value, Length: 12074, dtype: object

# %%
def function(a):
    if a != 'NaN':
        a = str(a).replace('%','')
    return float(a)

clv_num = data_set['customer_lifetime_value'].apply(function)
print(clv_num)
# Out:
# 0                NaN
# 1       6.979536e+05
# 2       1.288743e+06
# 3       7.645862e+05
# 4       5.363077e+05
#             ...
# 7065    2.340599e+04
# 7066    3.096511e+03
# 7067    8.163890e+03
# 7068    7.524442e+03
# 7069    2.611837e+03
# Name: customer_lifetime_value, Length: 12074, dtype: float64

# %%
#replacing NaN with numerical 0 value
clv_num = data_set['customer_lifetime_value'].fillna(value = 0)
clv_num
# Out:
# 0                 0
# 1        697953.59%
# 2       1288743.17%
# 3        764586.18%
# 4        536307.65%
#            ...
# 7065    23405.98798
# 7066    3096.511217
# 7067    8163.890428
# 7068    7524.442436
# 7069    2611.836866
# Name: customer_lifetime_value, Length: 12074, dtype: object

# %%
data_set['customer_lifetime_value'] = clv_num
data_set
# Out:
#      customer          st gender customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                       0      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
#check for duplicate rows
data_set.drop_duplicates()
# Out:
#      customer          st gender customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                       0      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
#filter out any 'income' less than 0
df_filtered = data_set[data_set['income'] > 0]

# %%
data_set = df_filtered

# %%
data_set
# Out:
#      customer          st gender customer_lifetime_value   income  \
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# 5     OC83172      Oregon      F              825629.78%  62902.0
# 6     XZ87318      Oregon      F              538089.86%  55350.0
# 8     DY87989      Oregon      M             2412750.40%  14072.0
# ...       ...         ...    ...                     ...      ...
# 7063  TF56202  California      M             5032.165498  66367.0
# 7064  YM19146  California      F             4100.398533  47761.0
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7068  UP19263  California      M             7524.442436  21941.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 2                    108.0   Personal Auto   Two-Door Car          566.472247
# ...
